# %%
import collections
from tqdm import tqdm
import numpy as np
import tensorflow as tf
import tensorflow_federated as tff

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

pil_im = Image.open('/pylon5/ir5fpvp/houc/fedgans_exps/images/client_steps=1,clients_per_round=1,status=CEN_CEN,model_name=adam_v18,client_batch=256/emnist_tff_gen_images_step_03039.png', 'r')
imshow(np.asarray(pil_im),cmap='gray', aspect='equal')

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

pil_im = Image.open('/pylon5/ir5fpvp/houc/fedgans_exps/images/client_steps=1,clients_per_round=8,status=CEN_FED,model_name=adam_v18,client_batch=32/emnist_tff_gen_images_step_03490.png', 'r')
imshow(np.asarray(pil_im),cmap='gray', aspect='equal')

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
pil_im = Image.open('/pylon5/ir5fpvp/houc/fedgans_exps/images/client_steps=1,clients_per_round=1,status=CEN_CEN,model_name=adam_v18,client_batch=256/emnist_tff_gen_images_step_04125.png', 'r')
imshow(np.asarray(pil_im),cmap='gray', aspect='equal')

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

pil_im = Image.open('/pylon5/ir5fpvp/houc/fedgans-9-18/images/client_steps=1,clients_per_round=8,status=CEN_FED,model_name=adam_v18,client_batch=32,optimizer=adam,lr=0.00025/emnist_tff_gen_images_step_14450.png', 'r')
imshow(np.asarray(pil_im),cmap='gray', aspect='equal')
